# %%
import pandas as pd
import numpy as np

# %%
filepath = 'D:\Python\PycharmProjects\Michael21\DataAnalyst.csv'
df = pd.read_csv(filepath,encoding='gb2312')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6876 entries, 0 to 6875
# Data columns (total 17 columns):
# city                 6876 non-null object
# companyFullName      6876 non-null object
# companyId            6876 non-null int64
# companyLabelList     6170 non-null object
# companyShortName     6876 non-null object
# companySize          6876 non-null object
# businessZones        4873 non-null object
# firstType            6869 non-null object
# secondType           6870 non-null object
# education            6876 non-null object
# industryField        6876 non-null object
# positionId           6876 non-null int64
# positionAdvantage    6876 non-null object
# positionName         6876 non-null object
# positionLables       6844 non-null object
# salary               6876 non-null object
# workYear             6876 non-null object
# dtypes: int64(2), object(15)
# memory usage: 510.4+ KB

# %%
df.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>city</th>
#       <th>companyFullName</th>
#       <th>companyId</th>
#       <th>companyLabelList</th>
#       <th>companyShortName</th>
#       <th>companySize</th>
#       <th>businessZones</th>
#       <th>firstType</th>
#       <th>secondType</th>
#       <th>education</th>
#       <th>industryField</th>
#       <th>positionId</th>
#       <th>positionAdvantage</th>
#       <th>positionName</th>
#       <th>positionLables</th>
#       <th>salary</th>
#       <th>workYear</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>上海</td>
#       <td>纽海信息技术(上海)有限公司</td>
#       <td>8581</td>
# ...

# %%
df.positionId.unique()
# Out:
# array([2537336, 2427485, 2511252, ..., 1832950, 2582349, 1757974], dtype=int64)

# %%
df_duplicates = df.drop_duplicates(subset='positionId',keep='first').head(5000)    #

# %%
df_duplicates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 5017
# Data columns (total 17 columns):
# city                 5000 non-null object
# companyFullName      5000 non-null object
# companyId            5000 non-null int64
# companyLabelList     4501 non-null object
# companyShortName     5000 non-null object
# companySize          5000 non-null object
# businessZones        3514 non-null object
# firstType            4996 non-null object
# secondType           4997 non-null object
# education            5000 non-null object
# industryField        5000 non-null object
# positionId           5000 non-null int64
# positionAdvantage    5000 non-null object
# positionName         5000 non-null object
# positionLables       4976 non-null object
# salary               5000 non-null object
# workYear             5000 non-null object
# dtypes: int64(2), object(15)
# memory usage: 410.2+ KB

# %%
def cut_word(word,method):
    position = word.find('-')
    length = len(word)
    if position != -1:
        bottomSalary = word[:position-1]
        topSalary = word[position+1:length-1]
    else:
        bottomSalary = word[:word.upper().find('K')]
        topSalary = bottomSalary
    if method == 'bottom':
        return bottomSalary
    else:
        return topSalary

# %%
df_duplicates['topSalary'] = df_duplicates.salary.apply(cut_word,method='top')
df_duplicates['bottomSalary'] = df_duplicates.salary.apply(cut_word,method='bottom')

# %%
df_duplicates.topSalary = df_duplicates.topSalary.astype('int')
df_duplicates.bottomSalary = df_duplicates.bottomSalary.astype('int')

# %%
df_duplicates['avgSalary'] = df_duplicates.apply(lambda x:(x.bottomSalary + x.topSalary)/2,axis=1)

# %%
df_clean = df_duplicates[['city','companyShortName','companySize',
                          'education','positionName','positionLables',
                          'workYear','avgSalary']]

# %%
df_clean.city.value_counts()
# Out:
# 北京    2342
# 上海     979
# 深圳     527
# 杭州     406
# 广州     335
# 成都     135
# 南京      83
# 武汉      69
# 西安      38
# 苏州      31
# 厦门      30
# 长沙      25
# Name: city, dtype: int64

# %%
df_clean.positionName.value_counts()
# Out:
# 数据分析师                               477
# 数据产品经理                              208
# 大数据开发工程师                            204
# 需求分析师                               109
# 数据分析                                 93
# 大数据工程师                               90
# 分析师                                  89
# 高级数据分析师                              72
# 大数据架构师                               65
# 商业数据分析                               64
# 数据开发工程师                              57
# 数据分析专员                               54
# 数据工程师                                52
# 大数据研发工程师                             48
# 数据仓库工程师                              43
# 数据分析工程师                              42
# 数据仓库                                 41
# 大数据产品经理                              35
# 数据科学家                                35
# 大数据分析师                               30
# 数据分析经理                               29
# 数据专员                                 28
# 资深数据分析师                              26
# ...

# %%
df_clean.describe()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>avgSalary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>5000.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>17.143900</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>8.991569</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>1.500000</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>11.500000</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>15.000000</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>22.500000</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>75.000000</td>
#     </tr>
# ...

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
df_clean.avgSalary.hist()

# %%
df_clean.avgSalary.hist(bins=25)

# %%
from matplotlib.font_manager import FontProperties

def font_change(ax):
    font_zh = FontProperties(fname=r"D:\Python\PycharmProjects\Michael21\simsun.ttc", size=14) #首先加载字体管理包，设置一个载入中文字体的变量
    for label in ax.get_xticklabels(): #ax.get_xticklabels获取坐标轴刻度，即无法正确显示城市名的白框，利用set_fontpeoperties更改字体。
        label.set_fontproperties(font_zh)
    ax.legend(prop=font_zh)

# %%
ax=df_clean.boxplot(column='avgSalary',by='city',figsize=(9,7))
font_change(ax)
# Out:
# D:\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
ax1=df_clean.boxplot(column='avgSalary',by='education',figsize=(9,7))
font_change(ax1)
# Out:
# D:\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
ax1=df_clean.boxplot(column='avgSalary',by='workYear',figsize=(9,7))
font_change(ax1)
# Out:
# D:\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
df_sh_bj = df_clean[df_clean['city'].isin(['上海','北京'])]
ax4 = df_sh_bj.boxplot(column='avgSalary',by=['education','city'],figsize=(14,6)) #column选择箱线图的数值，by是选择分类变量，figsize是尺寸
font_change(ax4)
# Out:
# D:\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
df_clean.groupby('city').count() # 按city列，针对不同城市进行了分组
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>companyShortName</th>
#       <th>companySize</th>
#       <th>education</th>
#       <th>positionName</th>
#       <th>positionLables</th>
#       <th>workYear</th>
#       <th>avgSalary</th>
#     </tr>
#     <tr>
#       <th>city</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>上海</th>
#       <td>979</td>
#       <td>979</td>
#       <td>979</td>
#       <td>979</td>
#       <td>973</td>
#       <td>979</td>
#       <td>979</td>
#     </tr>
#     <tr>
#       <th>北京</th>
# ...

# %%
df_clean.groupby('city').mean() # 换成mean，计算出了不同城市的平均薪资
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>avgSalary</th>
#     </tr>
#     <tr>
#       <th>city</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>上海</th>
#       <td>17.280388</td>
#     </tr>
#     <tr>
#       <th>北京</th>
#       <td>18.683604</td>
#     </tr>
#     <tr>
#       <th>南京</th>
#       <td>10.951807</td>
#     </tr>
#     <tr>
#       <th>厦门</th>
#       <td>10.966667</td>
#     </tr>
#     <tr>
#       <th>广州</th>
#       <td>12.702985</td>
#     </tr>
#     <tr>
#       <th>成都</th>
#       <td>12.848148</td>
#     </tr>
#     <tr>
#       <th>杭州</th>
#       <td>16.455665</td>
#     </tr>
#     <tr>
# ...

# %%
df_clean.groupby(['city','education']).mean() # 按城市和学历分组计算了平均薪资。
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>avgSalary</th>
#     </tr>
#     <tr>
#       <th>city</th>
#       <th>education</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="5" valign="top">上海</th>
#       <th>不限</th>
#       <td>14.051471</td>
#     </tr>
#     <tr>
#       <th>博士</th>
#       <td>15.000000</td>
#     </tr>
#     <tr>
#       <th>大专</th>
#       <td>13.395455</td>
#     </tr>
#     <tr>
#       <th>本科</th>
#       <td>17.987552</td>
#     </tr>
#     <tr>
#       <th>硕士</th>
#       <td>19.180000</td>
#     </tr>
#     <tr>
#       <th rowspan="5" valign="top">北京</th>
#       <th>不限</th>
# ...

# %%
df_clean.groupby(['city','education']).mean().unstack()  # 进行行列转置
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="5" halign="left">avgSalary</th>
#     </tr>
#     <tr>
#       <th>education</th>
#       <th>不限</th>
#       <th>博士</th>
#       <th>大专</th>
#       <th>本科</th>
#       <th>硕士</th>
#     </tr>
#     <tr>
#       <th>city</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>上海</th>
#       <td>14.051471</td>
#       <td>15.0</td>
#       <td>13.395455</td>
#       <td>17.987552</td>
#       <td>19.180000</td>
#     </tr>
#     <tr>
#       <th>北京</th>
#       <td>15.760163</td>
#       <td>25.0</td>
#       <td>12.339474</td>
# ...

# %%
df_clean.groupby(['city','education']).avgSalary.count().unstack() # 我们在groupby后面加一个avgSalary，说明只统计avgSalary的计数结果，不用混入相同数据
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>education</th>
#       <th>不限</th>
#       <th>博士</th>
#       <th>大专</th>
#       <th>本科</th>
#       <th>硕士</th>
#     </tr>
#     <tr>
#       <th>city</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>上海</th>
#       <td>68.0</td>
#       <td>3.0</td>
#       <td>110.0</td>
#       <td>723.0</td>
#       <td>75.0</td>
#     </tr>
#     <tr>
#       <th>北京</th>
#       <td>123.0</td>
#       <td>2.0</td>
#       <td>190.0</td>
#       <td>1873.0</td>
#       <td>154.0</td>
#     </tr>
#     <tr>
#       <th>南京</th>
#       <td>5.0</td>
# ...

# %%
df_clean.groupby('companyShortName').avgSalary.agg(['count','mean']).sort_values(by='count',ascending=False)
# 不同公司招聘的数据分析师数量，并且计算平均数
# agg函数，同时传入count和mean方法，然后返回了不同公司的计数和平均值两个结果
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#       <th>mean</th>
#     </tr>
#     <tr>
#       <th>companyShortName</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>美团点评</th>
#       <td>174</td>
#       <td>21.787356</td>
#     </tr>
#     <tr>
#       <th>滴滴出行</th>
#       <td>64</td>
#       <td>27.351562</td>
#     </tr>
#     <tr>
#       <th>百度</th>
#       <td>43</td>
#       <td>19.058140</td>
#     </tr>
#     <tr>
#       <th>网易</th>
#       <td>36</td>
#       <td>18.208333</td>
#     </tr>
#     <tr>
#       <th>腾讯</th>
#       <td>32</td>
#       <td>22.437500</td>
#     </tr>
#     <tr>
# ...

# %%
df_clean.groupby('companyShortName').avgSalary.agg(lambda x:max(x)-min(x))
# agg除了系统自带的几个函数，它也支持自定义函数。
# 返回了不同公司中最高薪资和最低薪资的差值。agg是一个很方便的函数，它能针对分组后的列数据进行丰富多彩的计算。
# Out:
# companyShortName
# 12580               0.0
# 12家全国性股份制商业银行之一     0.0
# 1号店                22.0
# 2345.com            4.0
# 360                22.0
# 360企业安全             0.0
# 360金融               0.0
# 4399                0.0
# 4399游戏              5.0
# 500.com集团          15.0
# 51Talk 无忧英语        15.0
# 51信用卡管家            20.0
# 51爱趣淘               0.0
# 55海淘                0.0
# 58到家               30.0
# 58车                 0.0
# APUS Group         27.0
# AbleCloud           2.5
# Adhub               0.0
# Alading Bank        0.0
# Asia-analytics      0.0
# Avazu Holding       0.0
# BBD                63.5
# BOE                 0.0
# BTCC                3.0
# BUGBANK             0.0
# BW                  5.5
# Baca                0.0
# Base FX             0.0
# Bindo Labs          0.0
#                    ...
# 驴妈妈旅游网             19.0
# 驻云                  0.0
# 高伟达软件股份有限公司        17.5
# 高升控股               12.5
# 高德联讯                0.0
# 高校邦                 0.0
# ...

# %%
计算出不同城市，招聘数据分析师需求前5的公司
def topN(df,n=5):
    counts = df.value_counts()
    return counts.sort_values(ascending=False)[:n]
df_clean.groupby('city').companyShortName.apply(topN)
# Out:
# city
# 上海    饿了么                 23
#       美团点评                19
#       买单侠                 15
#       返利网                 15
#       点融网                 11
# 北京    美团点评               155
#       滴滴出行                60
#       百度                  38
#       今日头条                32
#       百度外卖                31
# 南京    途牛旅游网                8
#       通联数据                 7
#       中地控股                 6
#       创景咨询                 5
#       竞情数据                 3
# 厦门    美图公司                 4
#       厦门融通信息技术有限责任公司       2
#       Datartisan 数据工匠      2
#       安居客                  1
#       渊亭信息科技               1
# 广州    探迹                  11
#       唯品会                  9
#       广东亿迅                 8
#       阿里巴巴移动事业群-UC         7
#       聚房宝                  6
# 成都    BBD                 12
#       景和千城                 4
#       货车帮                  3
#       知道创宇                 3
#       成都康赛                 3
# 杭州    个推                  22
#       网易                  15
# ...

# %%
df_clean.groupby('city').positionName.apply(topN)
font_change(ax1)
# Out:
# city
# 上海    数据分析师                79
#       大数据开发工程师             37
#       数据产品经理               31
#       大数据工程师               26
#       需求分析师                20
# 北京    数据分析师               238
#       数据产品经理              121
#       大数据开发工程师             69
#       分析师                  49
#       数据分析                 42
# 南京    大数据开发工程师              5
#       数据分析师                 5
#       大数据工程师                3
#       大数据架构师                3
#       数据规划（ 行业及美股数据方向）      2
# 厦门    数据分析专员                3
#       数据分析师                 3
#       大数据开发工程师              2
#       数据算法分析师               1
#       数据平台产品经理              1
# 广州    数据分析师                31
#       需求分析师                23
#       大数据开发工程师             13
#       数据分析专员               10
#       数据分析                  9
# 成都    大数据开发工程师             13
#       数据分析师                10
#       数据产品经理                8
#       大数据架构师                6
#       需求分析师                 4
# 杭州    数据分析师                44
# ...

# %%
df_clean.groupby('city').mean().plot.bar()

# %%
df_clean.groupby(['city','education']).mean().unstack().plot.bar(figsize=(14,6))
font_change(ax2)

# %%
# 将上海和北京的薪资数据以直方图的形式进行对比。因为北京和上海的分析师人数相差较远，所以无法直接对比，需要用normed参数转化为密度。设置alpha透明度，它比箱线图更直观。
plt.hist(x = df_clean[df_clean.city =="上海"].avgSalary,
        bins=15,
        normed=1,
        facecolor='blue',
        alpha=0.5)
plt.hist(x = df_clean[df_clean.city =="北京"].avgSalary,
        bins=15,
        normed=1,
        facecolor='red',
        alpha=0.5)
# Out:
# (array([  1.70794193e-02,   2.49220098e-02,   4.61841440e-02,
#           3.41588386e-02,   4.41799265e-02,   2.50091497e-02,
#           4.79269419e-03,   4.96697398e-03,   1.56851810e-03,
#           6.09979261e-04,   2.61419683e-04,   1.74279789e-04,
#           0.00000000e+00,   8.71398944e-05,   8.71398944e-05]),
#  array([  1.5,   6.4,  11.3,  16.2,  21.1,  26. ,  30.9,  35.8,  40.7,
#          45.6,  50.5,  55.4,  60.3,  65.2,  70.1,  75. ]),
#  <a list of 15 Patch objects>)

# %%
# 对数据进行深加工。我们将薪资设立出不同的level
# cut的作用是分桶，它也是数据分析常用的一种方法，将不同数据划分出不同等级，也就是将数值型数据加工成分类数据，在机器学习的特征工程中应用比较多。cut可以等距划分，传入一个数字就好。这里为了更好的区分，我传入了一组列表进行人工划分，加工成相应的标签。
bins = [0,3,5,10,15,20,30,100]
level = ['0-3','3-5','5-10','10-15','15-20','20-30','30-100']
df_clean['level'] = pd.cut(df_clean['avgSalary'],bins=bins,labels=level)
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
df_clean.groupby(['city','level']).avgSalary.count().unstack()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>level</th>
#       <th>0-3</th>
#       <th>3-5</th>
#       <th>5-10</th>
#       <th>10-15</th>
#       <th>15-20</th>
#       <th>20-30</th>
#       <th>30-100</th>
#     </tr>
#     <tr>
#       <th>city</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>上海</th>
#       <td>38.0</td>
#       <td>34.0</td>
#       <td>119.0</td>
#       <td>306.0</td>
#       <td>205.0</td>
#       <td>225.0</td>
#       <td>52.0</td>
#     </tr>
#     <tr>
#       <th>北京</th>
#       <td>53.0</td>
#       <td>108.0</td>
# ...

# %%
df_level = df_clean.groupby(['city','level']).avgSalary.count().unstack()
df_level_prop = df_level.apply(lambda x:x/x.sum(),axis=1)
axs = df_level_prop.plot.bar(stacked=True,figsize=(14,6))
font_change(axs)
用lambda转换百分比，然后作堆积百分比柱形图
(matplotlib好像没有直接调用的函数)。
这里可以较为清晰的看到不同等级在不同地区的薪资占比。
它比箱线图和直方图的好处在于，通过人工划分，具备业务含义。
0～3是实习生的价位，
3～6是刚毕业没有基础的新人，整理数据那种，
6～10是有一定基础的，以此类推。

# %%
len(df_clean.positionLables)
# Out:
# 5000

# %%
type(df_clean.positionLables)
# Out:
# pandas.core.series.Series

# %%
df_clean.positionLables.str[1:-1].str.replace(' ','')
#str方法允许我们针对列中的元素，进行字符串相关的处理，
# 这里的[1:-1]不再是DataFrame和Series的切片，而是对字符串截取，
# 这里把[]都截取掉了。如果漏了str，
# 就变成选取Series第二行至最后一行的数据
# 使用完str后，它返回的仍旧是Series，当我们想要再次用replace去除空格。
# 还是需要添加str的。
# Out:
# 0           '分析师','数据分析','数据挖掘','数据'
# 1           '分析师','数据分析','数据挖掘','数据'
# 2                  '分析师','数据分析','数据'
# 3              '商业','分析师','大数据','数据'
# 4             '分析师','数据分析','数据','BI'
# 5        '实习','投资','FA','行业研究','分析师'
# 6                               '数据'
# 7       '需求分析','顾问','咨询','咨询顾问','数据'
# 8                        '后端开发','数据'
# 9                               '数据'
# 10                   '平台','大数据','数据'
# 11                       '数据分析','数据'
# 12                  '数据分析','数据','BI'
# 13                              '数据'
# 14                        '大数据','数据'
# 15                              '数据'
# 16                        '大数据','数据'
# 17                        '分析师','内容'
# 18                             '分析师'
# 19                             '分析师'
# 20                              '数据'
# 21                             '分析师'
# 22             '商业','数据分析','数据','BI'
# 23                  '数据分析','仓储','数据'
# 24             '商业','数据分析','数据','BI'
# ...

# %%
# 通过apply和value_counts函数统计标签数。因为各行元素已经转换成了列表，
# 所以value_counts会逐行计算列表中的标签，apply的灵活性就在于此，
# 它将value_counts应用在行上，最后将结果组成一张新表。
word = df_clean.positionLables.str[1:-1].str.replace(' ','')
word.dropna().str.split(',').apply(pd.value_counts)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>'.NET'</th>
#       <th>'15天年假'</th>
#       <th>'Android'</th>
#       <th>'BD'</th>
#       <th>'BI'</th>
#       <th>'B端'</th>
#       <th>'C'</th>
#       <th>'C++'</th>
#       <th>'C/C++'</th>
#       <th>'CRM'</th>
#       <th>...</th>
#       <th>'音视频处理'</th>
#       <th>'项目管理'</th>
#       <th>'项目经理'</th>
#       <th>'顾问'</th>
#       <th>'风控'</th>
#       <th>'风险控制'</th>
#       <th>'餐饮'</th>
#       <th>'驾照'</th>
#       <th>'高校'</th>
#       <th>'高级'</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
# ...

# %%
# 用unstack完成行列转换，它是统计所有标签在各个职位的出现次数，绝大多数肯定是NaN。
df_word.unstack()
# Out:
# '.NET'  0      NaN
#         1      NaN
#         2      NaN
#         3      NaN
#         4      NaN
#         5      NaN
#         6      NaN
#         7      NaN
#         8      NaN
#         9      NaN
#         10     NaN
#         11     NaN
#         12     NaN
#         13     NaN
#         14     NaN
#         15     NaN
#         16     NaN
#         17     NaN
#         18     NaN
#         19     NaN
#         20     NaN
#         21     NaN
#         22     NaN
#         23     NaN
#         24     NaN
#         25     NaN
#         26     NaN
#         27     NaN
#         28     NaN
#         29     NaN
#                 ..
# '高级'    4988   NaN
#         4989   NaN
#         4990   NaN
#         4991   NaN
#         4992   NaN
#         4993   NaN
#         4994   NaN
#         4995   NaN
#         4996   NaN
#         4997   NaN
#         4998   NaN
#         4999   NaN
#         5000   NaN
#         5001   NaN
#         5002   NaN
#         5003   NaN
# ...

# %%
df_word.unstack().dropna().reset_index()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>level_0</th>
#       <th>level_1</th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>'.NET'</td>
#       <td>1397</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>'.NET'</td>
#       <td>2822</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>'.NET'</td>
#       <td>3765</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>'.NET'</td>
#       <td>3949</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>'.NET'</td>
#       <td>3954</td>
#       <td>1.0</td>
# ...

# %%
df_word.unstack().dropna().reset_index().groupby('level_0').count()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>level_1</th>
#       <th>0</th>
#     </tr>
#     <tr>
#       <th>level_0</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>'.NET'</th>
#       <td>6</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>'15天年假'</th>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>'Android'</th>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>'BD'</th>
#       <td>11</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>'BI'</th>
#       <td>200</td>
#       <td>200</td>
#     </tr>
#     <tr>
#       <th>'B端'</th>
# ...

# %%
df_word_counts = df_word.unstack().dropna().reset_index().groupby('level_0').count()
df_word_counts.index = df_word_counts.index.str.replace("'",'')
wordcloud = WordCloud(font_path='D:\\Python\\PycharmProjects\\Michael21\\simsun.ttc',
                      width=900,height=400,background_color='white')
wordcloud.fit_words(df_word_counts.level_1)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
